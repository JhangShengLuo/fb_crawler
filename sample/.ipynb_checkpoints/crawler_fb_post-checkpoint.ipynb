# %%
import requests
import datetime
import time
import pandas as pd

# %%
page_id = "crazyck101"

app_id = "393833577650615"
app_secret = "3ab280dac70995e4d8e601cbc025b53a"

access_token = app_id + "|" + app_secret

# %%
# 判斷response有無正常 正常 200，若無隔五秒鐘之後再試
def request_until_succeed(url):
    success = False
    while success is False:
        try: 
            req = requests.get(url)
            if req.status_code == 200:
                success = True
        except Exception as e:
            print(e)
            time.sleep(5)
            print("Error for URL %s: %s" % (url, datetime.datetime.now()))
            print("Retrying.")

    return req

# 取得Facebook data
def getFacebookPageFeedData(page_id, access_token, num_statuses):

    # Construct the URL string; see http://stackoverflow.com/a/37239851 for
    # Reactions parameters
    base = "https://graph.facebook.com/v2.8"
    node = "/%s/posts" % page_id 
    fields = "/?fields=message,link,created_time,type,name,id," + \
            "comments.limit(0).summary(true),shares,reactions" + \
            ".limit(0).summary(true)"
    parameters = "&limit=%s&access_token=%s" % (num_statuses, access_token)
    url = base + node + fields + parameters

    # 取得data
    data = request_until_succeed(url).json()
    return data

# 取得該篇文章的 reactions like,love,wow,haha,sad,angry數目
def getReactionsForStatus(status_id, access_token):

    # See http://stackoverflow.com/a/37239851 for Reactions parameters
        # Reactions are only accessable at a single-post endpoint

    base = "https://graph.facebook.com/v2.6"
    node = "/%s" % status_id
    reactions = "/?fields=" \
            "reactions.type(LIKE).limit(0).summary(total_count).as(like)" \
            ",reactions.type(LOVE).limit(0).summary(total_count).as(love)" \
            ",reactions.type(WOW).limit(0).summary(total_count).as(wow)" \
            ",reactions.type(HAHA).limit(0).summary(total_count).as(haha)" \
            ",reactions.type(SAD).limit(0).summary(total_count).as(sad)" \
            ",reactions.type(ANGRY).limit(0).summary(total_count).as(angry)"
    parameters = "&access_token=%s" % access_token
    url = base + node + reactions + parameters

    # 取得data
    data = request_until_succeed(url).json()
    return data

def processFacebookPageFeedStatus(status, access_token):

    # 要去確認抓到的資料是否為空
    status_id = status['id']
    status_type = status['type']
    if 'message' not in status.keys():
        status_message = ''
    else:
        status_message = status['message']
    if 'name' not in status.keys():
        link_name = ''
    else:
        link_name = status['name']
    link = status_id.split('_')
    
    # 此連結可以回到該臉書上的post
    status_link = 'https://www.facebook.com/'+link[0]+'/posts/'+link[1]

    status_published = datetime.datetime.strptime(status['created_time'],'%Y-%m-%dT%H:%M:%S+0000')
    # 根據所在時區 TW +8
    status_published = status_published + datetime.timedelta(hours=8)
    status_published = status_published.strftime('%Y-%m-%d %H:%M:%S') 
    
    # 要去確認抓到的資料是否為空
    if 'reactions' not in status:
        num_reactions = 0
    else:
        num_reactions = status['reactions']['summary']['total_count']
    if 'comments' not in status:
        num_comments = 0
    else:
        num_comments = status['comments']['summary']['total_count']
    if 'shares' not in status:
        num_shares = 0
    else:
        num_shares = status['shares']['count']

    def get_num_total_reactions(reaction_type, reactions):
        if reaction_type not in reactions:
            return 0
        else:
            return reactions[reaction_type]['summary']['total_count']
    
    # 取得該篇文章的 reactions like,love,wow,haha,sad,angry數目
    reactions = getReactionsForStatus(status_id, access_token)
    
    num_loves = get_num_total_reactions('love', reactions)
    num_wows = get_num_total_reactions('wow', reactions)
    num_hahas = get_num_total_reactions('haha', reactions)
    num_sads = get_num_total_reactions('sad', reactions)
    num_angrys = get_num_total_reactions('angry', reactions)
    num_likes = get_num_total_reactions('like', reactions)

    # 回傳tuple形式的資料
    return (status_id, status_message, link_name, status_type, status_link,
            status_published, num_reactions, num_comments, num_shares,
            num_likes, num_loves, num_wows, num_hahas, num_sads, num_angrys)


def scrapeFacebookPageFeedStatus(page_id, access_token):
    # all_statuses 用來儲存的list,先放入欄位名稱
    all_statuses = [('status_id', 'status_message', 'link_name', 'status_type', 'status_link',
            'status_published', 'num_reactions', 'num_comments', 'num_shares',
            'num_likes', 'num_loves', 'num_wows', 'num_hahas', 'num_sads', 'num_angrys')]
    
    has_next_page = True 
    num_processed = 0   # 計算處理多少post
    scrape_starttime = datetime.datetime.now()

    print("Scraping %s Facebook Page: %s\n" % (page_id, scrape_starttime))

    statuses = getFacebookPageFeedData(page_id, access_token, 100)

    while has_next_page:
        for status in statuses['data']:

            # 確定有 reaction 再把結構化後的資料存入 all_statuses
            if 'reactions' in status:
                all_statuses.append(processFacebookPageFeedStatus(status,access_token))

            # 觀察爬取進度,每處理100篇post,就輸出時間,
            num_processed += 1
            if num_processed % 100 == 0:
                print("%s Statuses Processed: %s" % (num_processed, datetime.datetime.now()))

        # 每超過100個post就會有next,可以從next中取得下100篇, 直到沒有next
        if 'paging' in statuses.keys():
            statuses = request_until_succeed(statuses['paging']['next']).json()
        else:
            has_next_page = False

    print("\nDone!\n%s Statuses Processed in %s" % \
        (num_processed, datetime.datetime.now() - scrape_starttime))
    
    return all_statuses

# %%
all_statuses = scrapeFacebookPageFeedStatus(page_id, access_token)
# Out:
# Scraping crazyck101 Facebook Page: 2017-03-26 16:45:31.948302
#
# 100 Statuses Processed: 2017-03-26 16:46:01.338110
# 200 Statuses Processed: 2017-03-26 16:46:31.131566
# 300 Statuses Processed: 2017-03-26 16:47:01.993215
# 400 Statuses Processed: 2017-03-26 16:47:32.004315
# 500 Statuses Processed: 2017-03-26 16:48:02.507580
#
# Done!
# 517 Statuses Processed in 0:02:36.667468

# %%
df = pd.DataFrame(all_statuses[1:], columns=all_statuses[0])

# %%
df.head()
# Out:
#                            status_id  \
# 0  1021581417961885_1231718840281474
# 1  1021581417961885_1230806240372734
# 2  1021581417961885_1230710647048960
# 3  1021581417961885_1230681773718514
# 4  1021581417961885_1229765993810092
#
#                                       status_message  \
# 0                                         趕稿中，明天晚上見喔
# 1  糟糕 以後要說94bb惹 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/...
# 2                                 禮拜一就要來抽獎囉！趕快分享不然掰掰
# 3    殺得你措手不及 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 4  百戰百勝 嘿嘿嘿！ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
#
#                                    link_name status_type  \
# 0                        68.media.tumblr.com        link
# 1  鄉民小心了！法院認證「87」是公然侮辱 - 生活 - 自由時報電子報｜卡提諾狂新聞        link
# 2                                     卡提諾狂新聞       video
# 3                               三寶的逆襲｜卡提諾狂新聞        link
# 4                              嚇到褲底ㄧ包｜卡提諾狂新聞        link
#
#                                          status_link     status_published  \
# 0  https://www.facebook.com/1021581417961885/post...  2017-03-25 17:12:34
# 1  https://www.facebook.com/1021581417961885/post...  2017-03-24 21:42:19
# 2  https://www.facebook.com/1021581417961885/post...  2017-03-24 19:43:14
# 3  https://www.facebook.com/1021581417961885/post...  2017-03-24 18:59:00
# 4  https://www.facebook.com/1021581417961885/post...  2017-03-23 21:27:45
#
#    num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0          10419           366          73       8516         46        62
# 1          12024           752        1184       8924         22       960
# 2           2261           632           0       2161         19         9
# 3           4327           141         156       3637         10       334
# 4           2439            73          34       2024          5        90
#
#    num_hahas  num_sads  num_angrys
# 0        957        23         815
# 1       2021        36          61
# 2         70         2           0
# 3        300        11          35
# 4         29         2         289

# %%
path = page_id+'_post.csv'
df.to_csv(path,index=False,encoding='utf8')

# %%
df
# Out:
#                              status_id  \
# 0    1021581417961885_1231718840281474
# 1    1021581417961885_1230806240372734
# 2    1021581417961885_1230710647048960
# 3    1021581417961885_1230681773718514
# 4    1021581417961885_1229765993810092
# 5    1021581417961885_1229316033855088
# 6    1021581417961885_1228690150584343
# 7    1021581417961885_1228337190619639
# 8    1021581417961885_1228223280631030
# 9    1021581417961885_1228173080636050
# 10   1021581417961885_1227361470717211
# 11   1021581417961885_1226861697433855
# 12   1021581417961885_1226432190810139
# 13   1021581417961885_1226406717479353
# 14   1021581417961885_1226278837492141
# 15   1021581417961885_1226221827497842
# 16   1021581417961885_1225501984236493
# 17   1021581417961885_1225484724238219
# 18   1021581417961885_1225318954254796
# 19   1021581417961885_1224135674373124
# 20   1021581417961885_1223387294447962
# 21   1021581417961885_1223371937782831
# 22   1021581417961885_1223331397786885
# 23   1021581417961885_1223290171124341
# 24   1021581417961885_1222523671200991
# 25   1021581417961885_1222500434536648
# 26   1021581417961885_1221873541266004
# 27   1021581417961885_1221674141285944
# 28   1021581417961885_1221554631297895
# 29   1021581417961885_1220703274716364
# ..                                 ...
# 487  1021581417961885_1031489970304363
# 488  1021581417961885_1031485223638171
# 489  1021581417961885_1031375616982465
# 490  1021581417961885_1031116203675073
# 491  1021581417961885_1030813197038707
# 492  1021581417961885_1029846297135397
# 493  1021581417961885_1029774007142626
# 494  1021581417961885_1029743570479003
# 495  1021581417961885_1029687257151301
# 496  1021581417961885_1029115717208455
# 497  1021581417961885_1028857467234280
# 498  1021581417961885_1028765440576816
# 499  1021581417961885_1028733127246714
# 500  1021581417961885_1027773560676004
# 501  1021581417961885_1027711120682248
# 502  1021581417961885_1024324787687548
# 503  1021581417961885_1026705077449519
# 504  1021581417961885_1026658750787485
# 505  1021581417961885_1024936557626371
# 506  1021581417961885_1024435981009762
# 507  1021581417961885_1024435174343176
# 508  1021581417961885_1024433291010031
# 509  1021581417961885_1024424271010933
# 510  1021581417961885_1024221367697890
# 511  1021581417961885_1023519924434701
# 512  1021581417961885_1023504487769578
# 513  1021581417961885_1023469851106375
# 514  1021581417961885_1023380531115307
# 515  1021581417961885_1022699851183375
# 516  1021581417961885_1022561054530588
#
#                                         status_message  \
# 0                                           趕稿中，明天晚上見喔
# 1    糟糕 以後要說94bb惹 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/...
# 2                                   禮拜一就要來抽獎囉！趕快分享不然掰掰
# 3      殺得你措手不及 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 4    百戰百勝 嘿嘿嘿！ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 5       何不食肉糜？ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 6                              小編下班回家收到一封信，內容我就不說了....
# 7    【狂抽猛送】第六集 「LINE旅遊大亨」\n\n沒有最狂只有更狂，這次狂抽猛送直接他媽帶你出...
# 8      來 這鍋誰扛？ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 9    晚上7點發佈【第6集狂抽猛送】\n　\n一樣保留部分獎項給前一萬樓留言\n而且這一集第一次要...
# 10   了不起。盜圖 #狂阿編\n#好圖不盜嗎\n\n提名投稿狂新聞>> https://goo.g...
# 11                                 請給這顆石頭一個讚，明天抽獎加碼送石頭
# 12   部長您要不要再想想？ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lr...
# 13   快找議員來幫忙抓一下 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lr...
# 14   讓點機會給其他人啦 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 15   午飯時間，來跟大家說個可喜可賀的好消息 #小助手\n又有兩台電視被中獎人領走啦~\n\n不用...
# 16   【0319】卡提諾狂新聞 #057\n\n● 重複留言絕對無法抽獎！\n　\n※ 第四名由於...
# 17                                          20：00 準時更新
# 18                                  我知道你們在等，一有消息我就告訴你們
# 19   委員 請問公蝦小嗎？ #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lr...
# 20   📣小助手來公佈【狂抽猛送 #5】得獎者名單\n本次獎項真的多到不.手.軟\n如果你是以下得...
# 21     議員您這是何苦 #狂阿編\n\n提名投稿狂新聞>> https://goo.gl/lrVe2h
# 22   先來公布吃飯不付錢的客人姓名\n阿不是....是分享那則貼文的得獎人姓名 #小助手\n\n【...
# 23                             半路撿到的。\n隨地亂丟的人，\n請自己舉手！
# 24                             狂抽猛送#5 抽獎補抽\n加贈 電影票、文具組
# 25          7點直播狂抽猛送抽獎補抽\n和早上答應的電影票跟文具組\n\n現在留言分享還來的及！
# 26   【分享此貼文抽電影票20張】\n【再加碼三組狂新聞文具組】\n  \n最狂的客人，吃飯不付錢...
# 27   📣小助手來公佈昨天抽獎的名單摟！\n請以下幸運的得獎者於本週日3/19 23:59前私訊粉...
# 28   這我只能說...94狂！ #狂阿編\n#用餐中請斟酌點閱 #別說我沒提醒你\n\n提名投稿狂...
# 29                                 狂抽猛送#5 星期四晚上20:00補抽
# ..                                                 ...
# 487  【0903】卡提諾狂新聞 #029 ※大力分享別客氣\n　\n「這週還是平平淡淡 」\n感謝...
# 488                             沒錯，小的又拖稿了\n【20分鐘內火速上傳】
# 489                                              此時的小編
# 490                        趕稿中，辦公室突然出現一隻老鼠\n　\n單兵如何處置？
# 491  期待的明天的狂新聞嗎？小編熬夜趕工中....\n大家先來預測一下吧\n　\n(現在直到明天中...
# 492  倒數最後１天　本週狂新聞４ni？\n　\n拖稿不可取　狂民來幫忙\n你若來Po文　愛瘋抽到爽...
# 493                                    亞拉肛...\n　\n#狂小編
# 494              人妖變臉那瞬間我嘴角莫名的抖了幾下 (#狂總管)\n　\n#中國大媽就是狂
# 495  今天看到這篇快笑死！（#狂總管)\n　\n#太狂\n#不分享對不起你們\n#如在進食請勿觀看\n
# 496                              我褲子都脫了結果他轉頭了\n　\n#狂小編
# 497                                         看得懂嗎？ #狂小編
# 498  我絕對不會承認這影片我看了三遍ヽ(`Д´)ノ（#狂總管）\n　\n#霸氣逼人\n#94狂\n...
# 499                                  #狂小編 的日常，請標籤出這樣的人
# 500  #太狂 \n#不能只有我看到\n#當你們是朋友才分享的哦\n#啾咪\n　\n( ^.＜ )\...
# 501                     好啦好啦 快滾！\n\n#94狂　\n　\n( #狂小編 )
# 502  狂民的PO文有如滔滔江水，連綿不絕，啊嘶～\niPhone 6狂抽猛送停不下來\nhttp:...
# 503                     這篇不算太狂\n但是蠻好笑的\n想睡覺時可看\n(#狂總管)
# 504             狂到不能再狂！不認識大傑的人...\n看完這篇總該認識了吧XD（#狂總管 ）
# 505  【0827】 卡提諾狂新聞 #028期\n精選一周最狂的給你！\n看完影片該標籤誰我想大家心...
# 506  【0723】 卡提諾狂新聞  #023期　\n看不過癮？快到卡提諾狂新聞網站看全部影片\nh...
# 507  【0716】 卡提諾狂新聞  #022期　\n看不過癮？快到卡提諾狂新聞網站看全部影片\nh...
# 508  【0709】卡提諾狂新聞 #021期\n看不過癮？快到卡提諾狂新聞網站看全部影片\nhttp...
# 509  【0702】 卡提諾狂新聞  #021期\n看不過癮？快到卡提諾狂新聞網站看全部影片\nht...
# 510  如果你願意，我可以幫你分析你的屌  \n　\n你以為就只有這樣？(掩嘴笑\n完整圖文版點這>...
# 511  師父，你也要去取經？　\n　\n#穿情侶鞋超瞎趴　\n#經還是精\n#不好意思我下流了\n\...
# 512  不覺得很酷嗎？(๑¯∀¯๑)\n三、四百個行李箱全都長得一模一樣\n#到底是想逼死誰\n#該...
# 513  如果你覺得這篇不好笑\n九成五不是我的問題\n一定是你笑點太高\n反正我是笑了\n#狂總管\...
# 514  #狂小編 說他某天發現家裡有這個，如果拿來當禮物有人想要嗎？(✪ω✪)（真心發問　\n　\n...
# 515  #太狂  #不能不分享 　\n　\n★狂新聞投稿之快來救救狂小編 \nhttp://craz...
# 516  我們這麼低調\n這粉絲團還是被大家發現了...#狂！！！\n好吧～第一則PO文，只好獻上近日...
#
#                                              link_name status_type  \
# 0                                  68.media.tumblr.com        link
# 1            鄉民小心了！法院認證「87」是公然侮辱 - 生活 - 自由時報電子報｜卡提諾狂新聞        link
# 2                                               卡提諾狂新聞       video
# 3                                         三寶的逆襲｜卡提諾狂新聞        link
# 4                                        嚇到褲底ㄧ包｜卡提諾狂新聞        link
# 5                4週彈性工時可連上24天 林美珠:不能說是血汗│中視新聞 20170323        link
# 6                                      Timeline Photos       photo
# 7                                【狂抽猛送】第六集 「LINE 旅遊大亨」       video
# 8                                       委員又講實話了｜卡提諾狂新聞        link
# 9                                      Timeline Photos       photo
# 10                                       議員，贏在偷圖，輸在改圖。        link
# 11                                     Timeline Photos       photo
# 12                       100分的部長，100的顏值，100分的幽默｜卡提諾狂新聞        link
# 13                                    好癢 抓不到...｜卡提諾狂新聞        link
# 14                                     Timeline Photos       photo
# 15                           Photos from 卡提諾狂新聞's post       photo
# 16                                   【0319】卡提諾狂新聞 #057       video
# 17                                                          status
# 18                                     Timeline Photos       photo
# 19              20170317中天新聞　繼林岱樺中油案　綠營再爆陳亭妃涉關說｜卡提諾狂新聞        link
# 20                                              卡提諾狂新聞       video
# 21                                 秘雕哥謝龍介新解9487｜卡提諾狂新聞        link
# 22                                                          status
# 23                                     Timeline Photos       photo
# 24                              狂抽猛送#5 抽獎補抽 加贈 電影票、文具組       video
# 25                                     Timeline Photos       photo
# 26                                                          status
# 27                                              卡提諾狂新聞       video
# 28                                  便便在....樹上？！｜卡提諾狂新聞        link
# 29                                                          status
# ..                                                 ...         ...
# 487                                  【0903】卡提諾狂新聞 #029       video
# 488                                                         status
# 489                                         p.fod4.com        link
# 490                                                         status
# 491                                    Timeline Photos       photo
# 492  【做你想做的狂新聞，遏制小編拖稿歪風】iPhone 6送給你！ | 狂新聞Crazy New...        link
# 493                                    cdn.acidcow.com        link
# 494         與泰國人妖合影...陸客大媽狂搓猛揉結果人妖生氣啦！一拳槌下去：我有的你也有(影影)        link
# 495              宿舍有人養馬！大號驚見「竹筍級」爆噁巨無霸便便...網友：這是浩克拉的吧！        link
# 496                                    Timeline Photos       photo
# 497                                          giphy.com        link
# 498           「證件在這！」屁孩秀出刺青想買菸 沒想到女店員竟抬起腿：瞬間逃出超商...(影)        link
# 499                                        i.giphy.com        link
# 500          躺在恐懼之上！超噁心的「巨大蟑螂充氣墊」絕對是最適合夏天的產品..也絕對最不受歡迎        link
# 501                                66.media.tumblr.com        link
# 502  【做你想做的狂新聞，遏制小編拖稿歪風】iPhone 6送給你！ | 狂新聞Crazy New...        link
# 503               姊姊撞見弟弟女友劈腿傳Line跟他講…但她用的貼圖實在太欠揍讓網友笑崩！        link
# 504         最狂大傑COS出爐！花博FF28神人「頭頂風扇」撐起三公尺長髮：完成度太高只能跪了!        link
# 505                                  【0827】卡提諾狂新聞 #028       video
# 506                                 【0723】卡提諾狂新聞  #023       video
# 507                                  【0716】卡提諾狂新聞 #022       video
# 508                                  【0709】卡提諾狂新聞 #021       video
# 509                                  【0702】卡提諾狂新聞 #021       video
# 510                                    Timeline Photos       photo
# 511                                    Timeline Photos       photo
# 512          整齊劃一的缺點！英國奧運選手風光返國 卻在機場傷透腦筋..行李都長一樣要怎麼分啦！        link
# 513                    嚇死誰！她收到「表弟藥包」照片感覺超無聊...但仔細看一秒噴笑        link
# 514                                    Timeline Photos       photo
# 515                                              半調子文青        link
# 516                                    Timeline Photos       photo
#
#                                            status_link     status_published  \
# 0    https://www.facebook.com/1021581417961885/post...  2017-03-25 17:12:34
# 1    https://www.facebook.com/1021581417961885/post...  2017-03-24 21:42:19
# 2    https://www.facebook.com/1021581417961885/post...  2017-03-24 19:43:14
# 3    https://www.facebook.com/1021581417961885/post...  2017-03-24 18:59:00
# 4    https://www.facebook.com/1021581417961885/post...  2017-03-23 21:27:45
# 5    https://www.facebook.com/1021581417961885/post...  2017-03-23 11:31:00
# 6    https://www.facebook.com/1021581417961885/post...  2017-03-22 22:48:18
# 7    https://www.facebook.com/1021581417961885/post...  2017-03-22 19:00:00
# 8    https://www.facebook.com/1021581417961885/post...  2017-03-22 12:00:00
# 9    https://www.facebook.com/1021581417961885/post...  2017-03-22 10:41:37
# 10   https://www.facebook.com/1021581417961885/post...  2017-03-21 16:41:06
# 11   https://www.facebook.com/1021581417961885/post...  2017-03-21 04:17:24
# 12   https://www.facebook.com/1021581417961885/post...  2017-03-20 20:30:04
# 13   https://www.facebook.com/1021581417961885/post...  2017-03-20 18:14:39
# 14   https://www.facebook.com/1021581417961885/post...  2017-03-20 14:25:08
# 15   https://www.facebook.com/1021581417961885/post...  2017-03-20 13:00:58
# 16   https://www.facebook.com/1021581417961885/post...  2017-03-19 19:53:24
# 17   https://www.facebook.com/1021581417961885/post...  2017-03-19 19:21:36
# 18   https://www.facebook.com/1021581417961885/post...  2017-03-19 14:54:44
# 19   https://www.facebook.com/1021581417961885/post...  2017-03-18 11:22:59
# 20   https://www.facebook.com/1021581417961885/post...  2017-03-17 17:09:01
# 21   https://www.facebook.com/1021581417961885/post...  2017-03-17 16:32:22
# 22   https://www.facebook.com/1021581417961885/post...  2017-03-17 15:14:52
# 23   https://www.facebook.com/1021581417961885/post...  2017-03-17 14:20:04
# 24   https://www.facebook.com/1021581417961885/post...  2017-03-16 19:12:58
# 25   https://www.facebook.com/1021581417961885/post...  2017-03-16 18:48:42
# 26   https://www.facebook.com/1021581417961885/post...  2017-03-16 01:41:38
# 27   https://www.facebook.com/1021581417961885/post...  2017-03-15 21:36:27
# 28   https://www.facebook.com/1021581417961885/post...  2017-03-15 18:26:03
# 29   https://www.facebook.com/1021581417961885/post...  2017-03-14 21:07:39
# ..                                                 ...                  ...
# 487  https://www.facebook.com/1021581417961885/post...  2016-09-03 12:28:34
# 488  https://www.facebook.com/1021581417961885/post...  2016-09-03 12:01:17
# 489  https://www.facebook.com/1021581417961885/post...  2016-09-03 09:41:31
# 490  https://www.facebook.com/1021581417961885/post...  2016-09-03 03:12:17
# 491  https://www.facebook.com/1021581417961885/post...  2016-09-02 20:51:25
# 492  https://www.facebook.com/1021581417961885/post...  2016-09-01 19:16:58
# 493  https://www.facebook.com/1021581417961885/post...  2016-09-01 17:09:42
# 494  https://www.facebook.com/1021581417961885/post...  2016-09-01 16:24:57
# 495  https://www.facebook.com/1021581417961885/post...  2016-09-01 15:07:28
# 496  https://www.facebook.com/1021581417961885/post...  2016-08-31 23:22:45
# 497  https://www.facebook.com/1021581417961885/post...  2016-08-31 19:03:59
# 498  https://www.facebook.com/1021581417961885/post...  2016-08-31 16:56:30
# 499  https://www.facebook.com/1021581417961885/post...  2016-08-31 16:22:04
# 500  https://www.facebook.com/1021581417961885/post...  2016-08-30 19:06:18
# 501  https://www.facebook.com/1021581417961885/post...  2016-08-30 17:00:36
# 502  https://www.facebook.com/1021581417961885/post...  2016-08-30 13:00:00
# 503  https://www.facebook.com/1021581417961885/post...  2016-08-29 15:01:06
# 504  https://www.facebook.com/1021581417961885/post...  2016-08-29 13:18:37
# 505  https://www.facebook.com/1021581417961885/post...  2016-08-27 12:36:23
# 506  https://www.facebook.com/1021581417961885/post...  2016-08-26 21:56:05
# 507  https://www.facebook.com/1021581417961885/post...  2016-08-26 21:54:39
# 508  https://www.facebook.com/1021581417961885/post...  2016-08-26 21:51:46
# 509  https://www.facebook.com/1021581417961885/post...  2016-08-26 21:39:52
# 510  https://www.facebook.com/1021581417961885/post...  2016-08-26 17:36:24
# 511  https://www.facebook.com/1021581417961885/post...  2016-08-25 19:51:54
# 512  https://www.facebook.com/1021581417961885/post...  2016-08-25 19:21:53
# 513  https://www.facebook.com/1021581417961885/post...  2016-08-25 18:33:41
# 514  https://www.facebook.com/1021581417961885/post...  2016-08-25 15:49:19
# 515  https://www.facebook.com/1021581417961885/post...  2016-08-24 20:32:51
# 516  https://www.facebook.com/1021581417961885/post...  2016-08-24 17:14:33
#
#      num_reactions  num_comments  num_shares  num_likes  num_loves  num_wows  \
# 0            10419           366          73       8516         46        62
# 1            12024           752        1184       8924         22       960
# 2             2261           632           0       2161         19         9
# 3             4327           141         156       3637         10       334
# 4             2439            73          34       2024          5        90
# 5             6778           502         438       4489         12       136
# 6            19613          1034          56      15364         35       645
# 7            27844         29618       31875      26944        103       150
# 8            10829           450         280       8820         22       102
# 9             2742           699         182       2591         21        16
# 10           13514           306         482      10526         31       168
# 11           42396           710          98      40186         60       284
# 12           12360           797         758       9365         28       150
# 13            2720            60          68       2265         10        12
# 14           18995           268          69      16762         37        51
# 15            5044           212          62       4777         24        91
# 16           62877         10065       12784      52359        405       164
# 17            8114           270          19       7122         28        59
# 18           21432           587          46      18015         31       113
# 19            5849           349         278       4533         11        80
# 20            1064            82           0        983          6         4
# 21            3935           110         170       3247         17        37
# 22            2206            80          20       1984         17        18
# 23            4487           115          14       4107          8        42
# 24            3700          3440        1192       3320        108        35
# 25            3664           668         293       3508         10        20
# 26           11891          2326        6116      11209         36       206
# 27            1214            64           0       1128          5         6
# 28            4286           259         246       3346         18       274
# 29            2390           113          13       2281          8        11
# ..             ...           ...         ...        ...        ...       ...
# 487          13867          1483        6301      12104         93        20
# 488            767            89           1        685          3         4
# 489            648            12          10        531          2         1
# 490            475            76           1        432          2         8
# 491            391            42           6        368          3         0
# 492            103             4           3        102          0         0
# 493            313            21          26        233          1         3
# 494            186             1           7        144          2         0
# 495            297            53          32        240          0        19
# 496            769            59          19        593          2        11
# 497            344            14          33        290          1         0
# 498            235             8           4        210          2         0
# 499            532            81          60        458         12         1
# 500            368            78          71        320          4        14
# 501            952            58         108        764         11         2
# 502             38             1           3         38          0         0
# 503            577            52          97        439          3         3
# 504            552             8         115        475          2        21
# 505           9001          1713        4240       7857         47        16
# 506           4528           207         412       3978         28        13
# 507           1560           165         262       1375          6         8
# 508           2449           102         375       2139         12         2
# 509           1015            56         117        891          0         2
# 510            186             7          12        152          1         0
# 511            112             2           3         96          1         0
# 512             85             0           0         71          0         0
# 513             77             2          10         53          0         1
# 514             87             7          11         74          1         1
# 515             73             5           0         56          1         6
# 516             90             0           1         78          2         1
#
#      num_hahas  num_sads  num_angrys
# 0          957        23         815
# 1         2021        36          61
# 2           70         2           0
# 3          300        11          35
# 4           29         2         289
# 5          589        36        1516
# 6         3352       140          77
# 7          637         4           6
# 8         1851         2          32
# 9          111         1           2
# 10        1972        16         801
# 11        1721        17         128
# 12        2739        13          65
# 13         429         1           3
# 14        2142         1           2
# 15          38        97          17
# 16        9887        19          43
# 17         393        11         501
# 18        1797        43        1433
# 19         755         8         462
# 20           5        61           5
# 21         631         2           1
# 22         130        48           9
# 23         329         0           1
# 24         120        68          49
# 25         117         6           3
# 26         431         3           6
# 27          22        43          10
# 28         614         8          26
# 29          43        36          11
# ..         ...       ...         ...
# 487       1646         0           4
# 488         70         2           3
# 489        110         4           0
# 490         33         0           0
# 491         20         0           0
# 492          1         0           0
# 493         76         0           0
# 494         40         0           0
# 495         36         1           1
# 496        155         3           5
# 497         53         0           0
# 498         23         0           0
# 499         59         2           0
# 500         24         2           4
# 501        175         0           0
# 502          0         0           0
# 503        130         1           1
# 504         53         0           1
# 505       1076         3           2
# 506        499         7           3
# 507        171         0           0
# 508        295         0           1
# 509        119         1           2
# 510         33         0           0
# 511         15         0           0
# 512         14         0           0
# 513         23         0           0
# 514         10         0           1
# 515         10         0           0
# 516          9         0           0
#
# [517 rows x 15 columns]
