# %%
import requests
import datetime
import json
import csv
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import traceback
import logging
import seaborn as sns
from pandas.io.json import json_normalize
# %matplotlib inline

import sys
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf-8')

# %%
def check_connect_output_json(url_address):
    limit_retry_number = 20
    for i in range(limit_retry_number):
        try :
            r = requests.get(url_address)
            if r.status_code == 200:
                r.encoding = "utf-8"
                jsondata = r.json()
                break
            else:
                print "retry ",i," times! 5sec between and retry only 20 times."
                print "else sleep"
                time.sleep(5)
        except (KeyboardInterrupt, SystemExit):
            raise
        except Exception as e:
            print "retry ",i," times! 5sec between and retry only 20 times."
            print "except sleep"
            time.sleep(5)
        if i == 20:
            return {"this url":{"is bad"}}
    return jsondata

def get_page_posts_to_df(url,page_num):
    
    jsondata = check_connect_output_json(url)['posts']
    testdf = pd.DataFrame()
    # 只要有分頁連結就一直往下
    x=0
    while 'paging' in jsondata:
        x +=1
        temp=json_normalize(jsondata['data'])
        temp = temp.drop(temp.ix[:,[0,7]],axis =1)
        id_list=temp["id"].tolist()
        
        append_temp = pd.DataFrame()
        for post_id in id_list:
            react_url=reactions_number(post_id,access_token)
            react_json=check_connect_output_json(react_url)
            react_temp=json_normalize(react_json)
            if len(react_temp.columns)== 13:
                react_temp = react_temp.drop(react_temp.ix[:,[0,2,5,7,9,11]],axis =1)
                react_temp.columns=['angry','haha','id','like','love','sad','wow']
            else:
                react_temp.assign(angry=0,haha=0,id=temp['id'],like=0,love=0,sad=0,wow=0)
          
            append_temp=append_temp.append(react_temp,ignore_index=True)
        
        merge_temp = pd.merge(append_temp,temp,on= "id")
        
        testdf=testdf.append(merge_temp,ignore_index=True)
        newurl = jsondata['paging']['next']
        newr= requests.get(newurl)
        newr.encoding="utf-8"
        jsondata = newr.json()
        print x,time.strftime("%Y-%m-%d %H:%M:%S", time.localtime())

        #若超過幾個分頁就先暫停
        if x==page_num:
            break
#     cl=['angry','haha','id','like','love','sad','wow','comments','create_time','link','message','name','reactions','shares','type']
#     testdf.columns= cl
    # 先不改時間格式，等全部抓下來再一起改，免得出錯。
#     testdf.create_time =pd.to_datetime(testdf.create_time,format= "%Y-%m-%dT%H:%M:%S+0000")
    
#     od=['id','type','create_time','link','message','name','angry','haha','like','love','sad','wow','reactions','comments','shares']
#     testdf=testdf[od]
    print "done"
    return testdf

# %%
def reactions_number(status_id,access_token):
    status_id = status_id

    base = "https://graph.facebook.com/v2.8"
    node = "/%s" % status_id
    reactions = "/?fields=" \
            "reactions.type(LIKE).limit(0).summary(total_count).as(like)" \
            ",reactions.type(LOVE).limit(0).summary(total_count).as(love)" \
            ",reactions.type(WOW).limit(0).summary(total_count).as(wow)" \
            ",reactions.type(HAHA).limit(0).summary(total_count).as(haha)" \
            ",reactions.type(SAD).limit(0).summary(total_count).as(sad)" \
            ",reactions.type(ANGRY).limit(0).summary(total_count).as(angry)"
    parameters = "&"+access_token
    url = base + node + reactions + parameters
#     print url
    return url
def fb_pages_info(page_id,access_token):
    # 選API版本預設2.8
    fb_graph_api = "https://graph.facebook.com/v2.8/"
    # 放粉絲頁ID
    nodes = page_id
    # access_token
    access_token = access_token
    # 所要看的欄位

    fields ="""/?fields=posts{id,name,link,message,shares,created_time,type,comments.limit(0).summary(total_count),reactions.limit(0).summary(total_count)}""" 
    # 把url連接整理好丟出去
    url = fb_graph_api+nodes+fields+"&"+access_token
    # status_id_url_end = fields+"&"+access_token
#     print url
    return url

app_id = "393833577650615"
app_secret = "3ab280dac70995e4d8e601cbc025b53a"

access_token = "access_token="+app_id + "|" + app_secret

page_id_list = ['YaoTurningTaipei','DoctorKoWJ','appledaily.tw',"gamer.com.tw","crazyck101","WoTBlitzTW"]

page_id = "WoTBlitzTW"

url = fb_pages_info(page_id,access_token)

# %%
r = requests.get(url)

r.encoding = "utf-8"
jsondata = r.json()['posts']
temp=json_normalize(jsondata['data'])
temp
# Out:
#    comments.data  comments.summary.total_count              created_time  \
# 0             []                             6  2017-04-14T11:02:20+0000
# 1             []                             1  2017-04-11T10:30:00+0000
# 2             []                             1  2017-04-11T05:48:35+0000
# 3             []                             3  2017-04-10T11:34:33+0000
# 4             []                             0  2017-04-10T10:00:00+0000
# 5             []                             7  2017-04-09T02:57:24+0000
# 6             []                             0  2017-04-08T08:02:04+0000
# 7             []                             0  2017-04-07T06:53:00+0000
# 8             []                             0  2017-04-06T13:09:29+0000
# 9             []                             8  2017-04-06T13:00:00+0000
# 10            []                            12  2017-04-06T10:00:00+0000
# 11            []                             0  2017-04-06T08:00:54+0000
# 12            []                             0  2017-04-05T10:30:32+0000
# 13            []                             0  2017-04-04T12:04:55+0000
# 14            []                             0  2017-04-04T10:30:31+0000
# 15            []                             0  2017-04-03T13:29:06+0000
# 16            []                            10  2017-04-03T12:00:00+0000
# 17            []                             0  2017-04-03T10:30:31+0000
# 18            []                             2  2017-04-02T13:30:30+0000
# 19            []                             2  2017-04-02T12:00:00+0000
# 20            []                            10  2017-04-01T12:00:00+0000
# 21            []                             5  2017-04-01T10:30:00+0000
# 22            []                             0  2017-03-31T13:06:55+0000
# 23            []                             8  2017-03-31T10:24:13+0000
# 24            []                             6  2017-03-31T09:46:33+0000
#
#                                    id  \
# 0   1504885679727769_1319557104764576
# 1   1504885679727769_1966286333587699
# 2   1504885679727769_1969919523224380
# 3   1504885679727769_1969498749933124
# 4   1504885679727769_1969439026605763
# 5   1504885679727769_1968854859997513
# 6   1504885679727769_1968287510054248
# 7   1504885679727769_1967615073454825
# 8   1504885679727769_1967109416838724
# 9   1504885679727769_1967017963514536
# 10  1504885679727769_1966970706852595
# 11  1504885679727769_1966975906852075
# 12  1504885679727769_1966325940250405
# 13  1504885679727769_1965804080302591
# 14  1504885679727769_1965767023639630
# 15  1504885679727769_1965285867021079
# 16  1504885679727769_1962624660620533
# 11  在 #戰遊網春季社群聚會 發現 Z270 CAMO SQUAD！\n無處不迷彩，戰無不勝！\...
# 12  這台 PS4 Slim 將會出現在 #戰遊網春季社群聚會 幸運者的手中！\n有簽有機會 👉...
# 13  這個六日你會到場嗎？精彩賽事、社群聚會、好吃好玩和滿滿的大獎好禮，都等你來戰！\n\n💥亞...
# 14  我們正在 #戰遊網春季社群聚會 捕獲 LG 29UM58 螢幕！ 4 月 8 日－9日來花博...
# 15  全亞洲都在 #戰遊網春季社群聚會 ！看看去年我們在馬來西亞、菲律賓、新加坡、日本、印尼、泰國...
# 16  「尖嘯風暴」迷彩\n這個傳奇迷彩僅適用於 M4A3E8 Sherman\n💥改變戰車的戰鬥...
# 17  不只玩遊戲...連平常看不到的地方，都要迷彩！\n迷彩顯卡 GEFORCE® GTX 106...
# 18  謝謝各位車長! #戰遊網春季社群聚會 報名幾乎額滿，好評再加開名額！\n如果你缺主機，XBO...
# 19  「幽靈」迷彩\n本罕見迷彩適用於所有車輛！\n\n💥會對符合所選欄位的地圖 +2–4% 車...
# 20  賞鳥影片－抓到自然棲息地的「白雁」！\n春天正是鳥兒從南方天空回家的時候，一對極為罕見的鳥兒...
# 21  #戰遊網春季社群聚會 倒數 7 天！你報了嗎？\n現在只要留言說出「你最喜歡或最想來社群聚會...
# 22  找滑鼠？就來 #戰遊網春季社群聚會！好吃、好喝、好好抽 MSI 微星 DS200 ！\n簽下...
# 23                               這個傷害...\n#tsk #comic
# 24  親愛的車長們：\n如果你們遇到有關 3.7 版更新的任何錯誤或問題都可以回報於此，請確保您的...
#
#                            name reactions.data  reactions.summary.total_count  \
# 0                           NaN             []                             74
# 1               Timeline Photos             []                             53
# 2        戰車世界：閃擊戰's cover photo             []                             52
# 3                      戰車世界：閃擊戰             []                             20
# 4               Timeline Photos             []                             35
# 5               Timeline Photos             []                             62
# 6               Timeline Photos             []                             44
# 7   Photos from 戰車世界：閃擊戰's post             []                             26
# 8               Timeline Photos             []                             12
# 9   Photos from 戰車世界：閃擊戰's post             []                            116
# 10  Photos from 戰車世界：閃擊戰's post             []                            104
# 11              Timeline Photos             []                             27
# 12              Timeline Photos             []                             30
# 13                    戰遊網春季社群聚會             []                             21
# 14              Timeline Photos             []                             17
# 15                          NaN             []                             39
# 16  Photos from 戰車世界：閃擊戰's post             []                             68
# 17              Timeline Photos             []                             23
# 18              Timeline Photos             []                             26
# 19  Photos from 戰車世界：閃擊戰's post             []                             49
# 20            白雁傳奇： 讓我們開始這趟旅程吧！             []                            179
# 21              Timeline Photos             []                             28
# 22              Timeline Photos             []                             26
# 23              Timeline Photos             []                            136
# 24                          NaN             []                             52
#
#     shares.count    type
# 0            2.0   video
# 1            NaN   photo
# 2            NaN   photo
# 3            NaN   photo
# 4            NaN   photo
# 5            NaN   photo
# 6            NaN   photo
# 7            NaN   photo
# 8            1.0   photo
# 9            1.0   photo
# 10           1.0   photo
# 11           NaN   photo
# 12           NaN   photo
# 13           NaN   event
# 14           NaN   photo
# 3                                             戰車世界：閃擊戰       20.0    1
# 4                                      Timeline Photos       35.0    0
# 5                                      Timeline Photos       62.0    2
# 6                                      Timeline Photos       44.0    0
# 7                          Photos from 戰車世界：閃擊戰's post       26.0    0
# 8                                      Timeline Photos       12.0    0
# 9                          Photos from 戰車世界：閃擊戰's post      116.0    1
# 10                         Photos from 戰車世界：閃擊戰's post      104.0    0
# 11                                     Timeline Photos       27.0    0
# 12                                     Timeline Photos       30.0    0
# 13                                           戰遊網春季社群聚會       21.0    0
# 14                                     Timeline Photos       17.0    0
# 15                                                 NaN       39.0    0
# 16                         Photos from 戰車世界：閃擊戰's post       68.0    0
# 17                                     Timeline Photos       23.0    0
# 18                                     Timeline Photos       26.0    0
# 19                         Photos from 戰車世界：閃擊戰's post       49.0    0
# 20                                   白雁傳奇： 讓我們開始這趟旅程吧！      179.0    2
# 21                                     Timeline Photos       28.0    0
# 22                                     Timeline Photos       26.0    0
# 23                                     Timeline Photos      136.0    0
# 24                                                 NaN       52.0    1
# 25                                            戰車世界：閃擊戰       19.0    0
# 26                                                 NaN       46.0    0
# 27                         Photos from 戰車世界：閃擊戰's post      173.0    0
# 28                                     Timeline Photos      101.0    0
# 29                                       Let's Battle！       53.0    0
# ..                                                 ...        ...  ...
# 898                                    Timeline Photos       59.0    0
# 899                                    Timeline Photos      982.0    0
# 900                                    Timeline Photos       19.0    0
# 901                                           戰車世界：閃擊戰       12.0    0
# 902                                    Timeline Photos       29.0    0
# 903                                    Timeline Photos       23.0    0
# 904                                    Timeline Photos       14.0    0
# 905                                    Timeline Photos       31.0    0
# 906                                    Timeline Photos       24.0    0
# 907                                           戰車世界：閃擊戰       14.0    0
# 908  [教學] 如何整合 Game Center 帳號與 Wargaming.net ID？ | ...       19.0    0
# 909                                    Timeline Photos       24.0    0
# 910                                    Timeline Photos       32.0    0
# 911                                    Timeline Photos       26.0    0
# 912                                    Timeline Photos       22.0    0
# 913                                    Timeline Photos       31.0    0
# 914                                    Timeline Photos       41.0    0
# 915                                    Timeline Photos       46.0    0
# 916                                    Timeline Photos      115.0    0
# 917                                    Timeline Photos       26.0    0
# 918       《戰車世界：閃擊戰》美術團隊專訪 | 新聞 | World of Tanks Blitz       10.0    0
# 919       組合包釋出：Dicker Max | 新聞 | World of Tanks Blitz       29.0    0
# 920                 金幣是什麼？ | 新聞 | World of Tanks Blitz       14.0    0
# 921  《戰車世界：閃擊戰》每日伺服器重置次數調整 | 遊戲內活動 | World of Tanks...       11.0    0
# 922                              【直播】手機遊戲輕鬆玩《戰車世界：閃擊戰》       10.0    0
# 923                                   《戰車世界：閃擊戰》行動裝置桌布        1.0    0
# 924                              《戰車世界：閃擊戰》科技樹（v1.1.0）        1.0    0
# 925                             戰車世界：閃擊戰's cover photo        NaN    0
# 926                             戰車世界：閃擊戰's cover photo        NaN    0
# 927                          Launched on June 26, 2014        NaN    0
#
#      shares    type  wow
# 0       2.0   video    0
# 1       NaN   photo    2
# 2       NaN   photo    0
# 3       NaN   photo    1
# 4       NaN   photo    0
# 5       NaN   photo    0
# 6       NaN   photo    4
# 7       NaN   photo    3
# 8       1.0   photo    0
# 9       1.0   photo    9
# 10      1.0   photo    7
# 11      NaN   photo    0
# 12      NaN   photo    0
# 13      NaN   event    0
# 14      NaN   photo    0
# 15      2.0   video    0
# 16      NaN   photo    0
# 17      NaN   photo    1
# 18      NaN   photo    1
# 19      NaN   photo    0
# 20      7.0   video    1
# 21      2.0   photo    0
# 22      NaN   photo    1
# 23      2.0   photo    1
# 24      2.0  status    0
# 25      NaN   photo    0
# 26      4.0   video    3
# 27     10.0   photo   12
# 28      1.0   photo    6
# 29      NaN   video    1
# ..      ...     ...  ...
# 898     3.0   photo    0
# 899     3.0   photo    0
# 900     NaN   photo    0
# 901     NaN   photo    0
# 902     NaN   photo    0
# 903     NaN   photo    0
# 904     NaN   photo    0
# 905     NaN   photo    0
# 906     NaN   photo    0
# 907     NaN   photo    0
# 908     NaN    link    0
# 909     NaN   photo    0
# 910     NaN   photo    0
# 911     1.0   photo    0
# 912     NaN   photo    0
# 913     NaN   photo    0
# 914     NaN   photo    0
# 915     1.0   photo    0
# 916     3.0   photo    0
# 917     6.0   photo    0
# 918     NaN    link    0
# 919     NaN    link    0
# 920     1.0    link    0
# 921     NaN    link    0
# 922     NaN    link    0
# 923     NaN   photo    0
# 924     NaN   photo    0
# 925     NaN   photo    0
# 926     NaN   photo    0
# 927     NaN   photo    0
#
# [928 rows x 15 columns]

# %%
datadf.columns=['angry','comments','created_time','haha','id','like','link','love','message','name','reactions','sad','shares','type','wow']

# %%
datadf=datadf[['angry','comments','created_time','haha','id','like','link','love','message','name','reactions','sad','shares','type','wow']]

# %%
fb_graph_api = "https://graph.facebook.com/v2.8"

page_id = "crazyck101"
edges = 'posts'
fields = "/?fields=message,link,created_time,type,name,id," + \
            "comments.limit(0).summary(true),shares,reactions" + \
            ".limit(0).summary(true)&limit=100&"
nodes = "/"+page_id+"/"+edges
app_id = "393833577650615"
app_secret = "3ab280dac70995e4d8e601cbc025b53a"
access_token = app_id + "|" + app_secret

url = fb_graph_api+nodes+fields+"access_token=%s"%(access_token)
print url
# Out:
# https://graph.facebook.com/v2.8/crazyck101/posts/?fields=message,link,created_time,type,name,id,comments.limit(0).summary(true),shares,reactions.limit(0).summary(true)&limit=100&access_token=393833577650615|3ab280dac70995e4d8e601cbc025b53a

# %%
status_id='1021581417961885_1194952983958060'

base = "https://graph.facebook.com/v2.8"
node = "/%s" % status_id
reactions = "/?fields=" \
        "reactions.type(LIKE).limit(0).summary(total_count).as(like)" \
        ",reactions.type(LOVE).limit(0).summary(total_count).as(love)" \
        ",reactions.type(WOW).limit(0).summary(total_count).as(wow)" \
        ",reactions.type(HAHA).limit(0).summary(total_count).as(haha)" \
        ",reactions.type(SAD).limit(0).summary(total_count).as(sad)" \
        ",reactions.type(ANGRY).limit(0).summary(total_count).as(angry)"
parameters = "&access_token=%s" % access_token
url = base + node + reactions + parameters
